# %%
# import operaciones_basicas as ob
from operaciones_basicas import operaciones_aritmeticas as oa
from operaciones_basicas import operaciones_comparacion as oc

# %%
#Prueba01
a = float(input("ingrese el primer numero: \n"))
b = float(input("ingrese el segundo numero: \n"))
# Out:
# ingrese el primer numero:
#  2
# ingrese el segundo numero:
#  3

# %%
suma = oa.sumar(a,b)
resta = oa.restar(a,b)
multiplicacion = oa.multiplicar(a,b)
division = oa.dividir(a,b)
# Out:
# El resultado de la suma es: 5.0
# El resultado de la resta es: -1.0
# El resultado de la multiplicacion es: 6.0
# El resultado de la division es: 0.6666666666666666

# %%
resultado = oc.mayor(a,b)
# Out:
# El argumento 2.0 es mayor que el argumento 3.0

# %%
print(resultado)
# Out:
# False
